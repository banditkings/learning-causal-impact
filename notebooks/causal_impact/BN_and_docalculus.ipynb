# %% [markdown]
# # Introducing Causal Inference with Bayesian Networks and do-Calculus
#
# In contrast to Potential Outcomes (PO), I'm going back and revisiting Pearl's Structural Causal Models (SCM), do-Calculus, and Bayesian Networks.
#
# Wrapping my head around the difference between the observational distribution $p(y|x)$ vs the *interventional* distribution $p(y|do(x))$. I think most questions I deal with are of the $p(y|do(x))$ variety in which I want to estimate the distribution of $y$ if I intervene on $x$.
#
# ## Reference
#
# * [Interventional distributions and graph utation with the do-operator](https://www.pymc.io/projects/examples/en/latest/causal_inference/interventional_distribution.html)
# * [Introducing Causal Inference Using Bayesian Networks and *do*-Calculus. (Lu, Zheng, & Quinn, 2022)](https://www.tandfonline.com/doi/full/10.1080/26939169.2022.2128118)
# * [BNandCausalinference Shiny App](https://alyeskabear.shinyapps.io/BNandCausalinference/)
# * [Introductions to Causal Calculus](https://www.cs.ubc.ca/labs/lci/mlrg/slides/doCalc.pdf)
# * [ML beyond Curve Fitting: An Intro to Causal Inference and do-Calculus](https://www.inference.vc/untitled/)

# %%
import graphviz as gr

# %% [markdown]
# Recall the simplest DAG with two nodes and one edge:

# %%
g = gr.Digraph("simple_DAG", graph_attr={'rankdir':'LR'})
g.edge('X', 'Y')
g

# %% [markdown]
# This simple BN is a model that describes the joint probability $p(X,Y)$, and the direction indicates:
#
# $$
# p(X,Y) = p(Y|X)p(X)
# $$
#
# using the multiplication rule.
